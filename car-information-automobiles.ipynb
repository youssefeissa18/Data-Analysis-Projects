# %% [markdown]
# # import needed Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Reading the Data

# %%
df = pd.read_csv("/kaggle/input/automobile-dataset/Automobile.csv")

# %% [markdown]
# * Name: Unique identifier for each automobile.
# * MPG: Fuel efficiency measured in miles per gallon.
# * Cylinders: Number of cylinders in the engine.
# * Displacement: Engine displacement, indicating its size or capacity.
# * Horsepower: Power output of the engine.
# * Weight: Weight of the automobile.
# * Acceleration: Capability to increase speed, measured in seconds.
# * Model Year: Year of manufacture for the automobile model.
# * Origin: Country or region of origin for each automobile.

# %% [markdown]
# # Exploring the Data

# %%
df.shape
# Out:
# (398, 9)

# %%
df.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1          buick skylark 320  15.0          8         350.0       165.0
# 2         plymouth satellite  18.0          8         318.0       150.0
# 3              amc rebel sst  16.0          8         304.0       150.0
# 4                ford torino  17.0          8         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0    3504          12.0          70    usa
# 1    3693          11.5          70    usa
# 2    3436          11.0          70    usa
# 3    3433          12.0          70    usa
# 4    3449          10.5          70    usa

# %%
df.tail()
# Out:
#                 name   mpg  cylinders  displacement  horsepower  weight  \
# 393  ford mustang gl  27.0          4         140.0        86.0    2790
# 394        vw pickup  44.0          4          97.0        52.0    2130
# 395    dodge rampage  32.0          4         135.0        84.0    2295
# 396      ford ranger  28.0          4         120.0        79.0    2625
# 397       chevy s-10  31.0          4         119.0        82.0    2720
#
#      acceleration  model_year  origin
# 393          15.6          82     usa
# 394          24.6          82  europe
# 395          11.6          82     usa
# 396          18.6          82     usa
# 397          19.4          82     usa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          398 non-null    object
#  1   mpg           398 non-null    float64
#  2   cylinders     398 non-null    int64
#  3   displacement  398 non-null    float64
#  4   horsepower    392 non-null    float64
#  5   weight        398 non-null    int64
#  6   acceleration  398 non-null    float64
#  7   model_year    398 non-null    int64
#  8   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# **The data info show no null value**

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# **from the data we can see the mean and min max for all column lets show**
# **in mpg mean is 23.514573 min 9.000000 and max is 46.600000**
# **in horsepower mean is 104.469388 min is 46.000000 max is 230.000000**

# %%
df.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %% [markdown]
# **there are not any nan value**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **There are not duplicated value**

# %% [markdown]
# # Cleaning the Data

# %%
df.columns
# Out:
# Index(['name', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %%
df.rename(columns={'name' : 'Name', 'mpg':'Miles Per Gallon', 
                   'cylinders':'Cylinders', 'displacement':'Displacement', 'horsepower':'HorsePower', 
                   'weight':'Weight','acceleration':'Acceleration', 
                   'model_year': 'Model_Year', 'origin':'Origin'},inplace=True)

# %%
df.head()
# Out:
#                         Name  Miles Per Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    HorsePower  Weight  Acceleration  Model_Year Origin
# 0       130.0    3504          12.0          70    usa
# 1       165.0    3693          11.5          70    usa
# 2       150.0    3436          11.0          70    usa
# 3       150.0    3433          12.0          70    usa
# 4       140.0    3449          10.5          70    usa

# %% [markdown]
# **Rename some column to make it more readable**

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              392 non-null    object
#  1   Miles Per Gallon  392 non-null    float64
#  2   Cylinders         392 non-null    int64
#  3   Displacement      392 non-null    float64
#  4   HorsePower        392 non-null    float64
#  5   Weight            392 non-null    int64
#  6   Acceleration      392 non-null    float64
#  7   Model_Year        392 non-null    int64
#  8   Origin            392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %% [markdown]
# **Remove null value**

# %% [markdown]
# # Analysis and Visualization

# %%
df.head()
# Out:
#                         Name  Miles Per Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    HorsePower  Weight  Acceleration  Model_Year Origin
# 0       130.0    3504          12.0          70    usa
# 1       165.0    3693          11.5          70    usa
# 2       150.0    3436          11.0          70    usa
# 3       150.0    3433          12.0          70    usa
# 4       140.0    3449          10.5          70    usa

# %% [markdown]
# **The number of models**

# %%
count_models = df['Name'].value_counts().reset_index().head(100)
count_models
# Out:
#                 Name  count
# 0        amc matador      5
# 1         ford pinto      5
# 2     toyota corolla      5
# 3      toyota corona      4
# 4         amc hornet      4
# ..               ...    ...
# 95  mercury zephyr 6      1
# 96   plymouth volare      1
# 97   ford fairmont 4      1
# 98  amc concord dl 6      1
# 99     dodge aspen 6      1
#
# [100 rows x 2 columns]

# %%
xticks = count_models['Name']
plt.figure(figsize=(20,12))
plt.bar(count_models['Name'],count_models['count'],color='darkred')
plt.xticks(xticks,rotation=90)
plt.title("Model VS Count")
plt.xlabel("Model")
plt.ylabel("Count")
plt.legend()
plt.show()

# %% [markdown]
# <h2>Origin<h2>

# %%
origins = df.groupby('Origin')['Origin'].value_counts().reset_index()
origins
# Out:
#    Origin  count
# 0  europe     68
# 1   japan     79
# 2     usa    245

# %%
plt.figure(figsize=(8,8))
plt.pie(origins['count'], labels=origins['Origin'],autopct='%1.3f%%',explode=[0,0.1,0.1],shadow=True,colors=['#1DB954','darkred','brown'])
plt.legend()
plt.show()

# %% [markdown]
# **this pie show the more cars comes from USA**

# %% [markdown]
# <h2>Model Year<h2>

# %%
Model_Year = df['Model_Year'].value_counts().reset_index().sort_values(by='Model_Year',ascending=False)
Model_Year
# Out:
#     Model_Year  count
# 4           82     30
# 9           81     28
# 11          80     27
# 6           79     29
# 1           78     36
# 8           77     28
# 2           76     34
# 3           75     30
# 12          74     26
# 0           73     40
# 7           72     28
# 10          71     27
# 5           70     29

# %%
xticks = Model_Year['Model_Year']
plt.figure(figsize=(8,8))
plt.bar(Model_Year['Model_Year'],Model_Year['count'],color='darkred')
plt.xticks(xticks,rotation=90)
plt.title("Model_Year VS Count")
plt.xlabel("Model_Year")
plt.ylabel("Count")
plt.legend()
plt.show()

# %% [markdown]
# <h2>Acceleration<h2>

# %% [markdown]
# <h2>Top 20 Acceleration with Acceleration<h2>

# %%
Acceleration = df['Acceleration'].value_counts().reset_index().sort_values(by='Acceleration',ascending=False).head(20)
Acceleration
# Out:
#     Acceleration  count
# 82          24.8      1
# 76          24.6      1
# 68          23.7      1
# 87          23.5      1
# 61          22.2      2
# 93          22.1      1
# 92          21.9      1
# 66          21.8      1
# 77          21.7      1
# 88          21.5      1
# 23          21.0      5
# 71          20.7      1
# 51          20.5      2
# 73          20.4      1
# 53          20.1      2
# 67          19.9      1
# 57          19.6      2
# 18          19.5      6
# 37          19.4      3
# 38          19.2      3

# %%
xticks = Acceleration['Acceleration']
plt.figure(figsize=(8,8))
plt.bar(Acceleration['Acceleration'],Acceleration['count'],color='darkred',width=0.4)
plt.xticks(xticks,rotation=90)
plt.title("Acceleration VS Count")
plt.xlabel("Acceleration")
plt.ylabel("Count")
plt.legend()
plt.show()

# %% [markdown]
# <h2>Top 10 Acceleration With name<h2>

# %%
top_10_accelerations = df.groupby('Name')['Acceleration'].value_counts().sort_values(ascending=False).head(10).reset_index()
top_10_accelerations
# Out:
#                     Name  Acceleration  count
# 0  ford gran torino (sw)          16.0      2
# 1       chevrolet impala          12.0      2
# 2           datsun pl510          14.5      2
# 3            dodge aspen          18.7      2
# 4            amc gremlin          15.0      2
# 5            honda civic          15.0      2
# 6         chevrolet vega          19.5      2
# 7             amc hornet          16.0      2
# 8             datsun 210          19.2      2
# 9             opel manta          14.5      1

# %%
xticks = top_10_accelerations['Name']
plt.figure(figsize=(8,8))
plt.bar(top_10_accelerations['Name'],top_10_accelerations['Acceleration'],color='darkred')
plt.xticks(xticks,rotation=90)
plt.title("top_10_accelerations")
plt.xlabel("Name")
plt.ylabel("Acceleration")
plt.legend()
plt.show()

# %% [markdown]
# <h2>Top 20 Acceleration with other<h2>

# %%
all_Acceleration = df['Acceleration'].value_counts().reset_index()
all_Acceleration
# Out:
#     Acceleration  count
# 0           14.5     23
# 1           15.5     21
# 2           14.0     16
# 3           16.0     16
# 4           13.5     15
# ..           ...    ...
# 90          11.1      1
# 91          12.1      1
# 92          21.9      1
# 93          22.1      1
# 94          11.6      1
#
# [95 rows x 2 columns]

# %%
plt.figure(figsize=(8,8))
plt.pie([len(Acceleration),len(all_Acceleration)-len(Acceleration)],labels = ['Top 20 Acceleration', 'Other Acceleration'],autopct='%1.3f%%',explode=[0.1,0],shadow=True,colors=['#1DB954','darkred'])
plt.legend()
plt.show()

# %% [markdown]
# <h2>Horse Power<h2>

# %% [markdown]
# **Top 10 car have Horse Power**

# %%
top_10_horsepower = df.groupby('Name')['HorsePower'].value_counts().reset_index().sort_values(by='HorsePower',ascending=False).head(10)
top_10_horsepower
# Out:
#                              Name  HorsePower  count
# 298            pontiac grand prix       230.0      1
# 35       buick electra 225 custom       225.0      1
# 37        buick estate wagon (sw)       225.0      1
# 295              pontiac catalina       225.0      1
# 73               chevrolet impala       220.0      1
# 274             plymouth fury iii       215.0      1
# 98   chrysler new yorker brougham       215.0      1
# 163                     ford f250       215.0      1
# 140                    dodge d200       210.0      1
# 237               mercury marquis       208.0      1

# %%
xticks = top_10_horsepower['Name']
plt.figure(figsize=(8,8))
plt.bar(top_10_horsepower['Name'],top_10_horsepower['HorsePower'],color='darkred')
plt.xticks(xticks,rotation=90)

plt.title("top_10_horsepower")
plt.xlabel("Name")
plt.ylabel("HorsePower")
plt.legend()
plt.show()

# %% [markdown]
# **Top 10 horsePower with other**

# %%
all_horse_power = df['HorsePower'].value_counts().reset_index()
all_horse_power
# Out:
#     HorsePower  count
# 0        150.0     22
# 1         90.0     20
# 2         88.0     19
# 3        110.0     18
# 4        100.0     17
# ..         ...    ...
# 88        61.0      1
# 89        93.0      1
# 90       148.0      1
# 91       152.0      1
# 92        82.0      1
#
# [93 rows x 2 columns]

# %%
plt.figure(figsize=(8,8))
plt.pie([len(top_10_horsepower),len(all_horse_power)-len(top_10_horsepower)],labels = ['Top 10 HorsePower', 'Other HorsePower'],autopct='%1.3f%%',explode=[0.1,0],shadow=True,colors=['#1DB954','darkred'])
plt.legend()
plt.show()

# %% [markdown]
# <h2>The HorsePower of car and the Acceleration<h2>

# %%
df.head()
# Out:
#                         Name  Miles Per Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    HorsePower  Weight  Acceleration  Model_Year Origin
# 0       130.0    3504          12.0          70    usa
# 1       165.0    3693          11.5          70    usa
# 2       150.0    3436          11.0          70    usa
# 3       150.0    3433          12.0          70    usa
# 4       140.0    3449          10.5          70    usa

# %%
Acceleration_HorsePower = df.groupby('HorsePower')['Acceleration'].value_counts().reset_index().sort_values(by='HorsePower',ascending=False)
Acceleration_HorsePower
# Out:
#      HorsePower  Acceleration  count
# 345       230.0           9.5      1
# 344       225.0          11.0      1
# 343       225.0          10.0      2
# 342       220.0           9.0      1
# 341       215.0          14.0      1
# ..          ...           ...    ...
# 4          48.0          23.7      1
# 2          48.0          21.5      1
# 3          48.0          21.7      1
# 1          46.0          21.0      1
# 0          46.0          20.5      1
#
# [346 rows x 3 columns]

# %% [markdown]
# **From show the data we found when hourse power is small the  Acceleration is become big and vis and show this in graph**

# %%
xticks = Acceleration['Acceleration']

plt.figure(figsize=(8, 8))
plt.plot(Acceleration_HorsePower['HorsePower'], Acceleration_HorsePower['Acceleration'],color='darkred')
plt.xlabel('HorsePower')
plt.ylabel('Acceleration')
plt.title('HorsePower vs. Acceleration')
plt.show()

# %% [markdown]
# <h2>Displacement<h2>

# %% [markdown]
# **Top 10 Displacement**

# %%
top_10_Displacement = df.groupby('Name')['Displacement'].value_counts().reset_index().sort_values(by='Displacement',ascending=False).head(10)
top_10_Displacement
# Out:
#                              Name  Displacement  count
# 36        buick estate wagon (sw)         455.0      1
# 34       buick electra 225 custom         455.0      1
# 272              pontiac catalina         455.0      1
# 68               chevrolet impala         454.0      1
# 253             plymouth fury iii         440.0      1
# 90   chrysler new yorker brougham         440.0      1
# 218               mercury marquis         429.0      1
# 219      mercury marquis brougham         429.0      1
# 163              ford galaxie 500         429.0      1
# 148                  ford country         400.0      1

# %%
xticks = top_10_Displacement['Name']
plt.figure(figsize=(8,8))
plt.bar(top_10_Displacement['Name'],top_10_Displacement['Displacement'],color='darkred')
plt.xticks(xticks,rotation=90)

plt.title("top_10_Displacement")
plt.xlabel("Name")
plt.ylabel("Displacement")
plt.legend()
plt.show()

# %% [markdown]
# **Displacement with other**

# %%
all_Displacement = df['Displacement'].value_counts().reset_index()
all_Displacement
# Out:
#     Displacement  count
# 0           97.0     21
# 1          350.0     18
# 2           98.0     17
# 3          318.0     17
# 4          250.0     17
# ..           ...    ...
# 76         104.0      1
# 77         110.0      1
# 78         130.0      1
# 79         111.0      1
# 80         144.0      1
#
# [81 rows x 2 columns]

# %%
plt.figure(figsize=(8,8))
plt.pie([len(top_10_Displacement),len(all_Displacement)-len(top_10_Displacement)],labels = ['Top 10  isplacement', 'Other Displacement'],autopct='%1.3f%%',explode=[0.1,0],shadow=True,colors=['#1DB954','darkred'])
plt.legend()
plt.show()

# %% [markdown]
# **Displacement with Horse Power**

# %%
df.head()
# Out:
#                         Name  Miles Per Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    HorsePower  Weight  Acceleration  Model_Year Origin
# 0       130.0    3504          12.0          70    usa
# 1       165.0    3693          11.5          70    usa
# 2       150.0    3436          11.0          70    usa
# 3       150.0    3433          12.0          70    usa
# 4       140.0    3449          10.5          70    usa

# %%
DisplacementwithHorsePower = df.groupby('Name')[['Displacement','HorsePower']].value_counts().reset_index().sort_values(by='Displacement',ascending=False)
DisplacementwithHorsePower
# Out:
#                          Name  Displacement  HorsePower  count
# 38    buick estate wagon (sw)         455.0       225.0      1
# 36   buick electra 225 custom         455.0       225.0      1
# 296          pontiac catalina         455.0       225.0      1
# 74           chevrolet impala         454.0       220.0      1
# 275         plymouth fury iii         440.0       215.0      1
# ..                        ...           ...         ...    ...
# 324       toyota corolla 1200          71.0        65.0      2
# 219                 maxda rx3          70.0        90.0      1
# 228             mazda rx-7 gs          70.0       100.0      1
# 229           mazda rx2 coupe          70.0        97.0      1
# 153                  fiat 128          68.0        49.0      1
#
# [370 rows x 4 columns]

# %%
plt.figure(figsize=(8, 8))
plt.plot(DisplacementwithHorsePower['Displacement'],DisplacementwithHorsePower['HorsePower'])
plt.xlabel('Displacement')
plt.ylabel('HorsePower')
plt.title('Displacement VS HorsePower')
plt.show()

# %% [markdown]
# **This grap show when the Displacement become big the HorsePower become big**

# %% [markdown]
# <h2>Cylinders<h2>

# %%
df.head()
# Out:
#                         Name  Miles Per Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    HorsePower  Weight  Acceleration  Model_Year Origin
# 0       130.0    3504          12.0          70    usa
# 1       165.0    3693          11.5          70    usa
# 2       150.0    3436          11.0          70    usa
# 3       150.0    3433          12.0          70    usa
# 4       140.0    3449          10.5          70    usa

# %%
Cylinders = df['Cylinders'].value_counts().reset_index()
Cylinders
# Out:
#    Cylinders  count
# 0          4    199
# 1          8    103
# 2          6     83
# 3          3      4
# 4          5      3

# %%
plt.figure(figsize=(8,8))
plt.pie(Cylinders['count'],shadow=True, autopct='%1.1f%%',labels=Cylinders['Cylinders'],explode=[0,0,0,0.6,0.9])
plt.legend()
plt.axis('equal')
plt.title('Cylinders')
# Out:
# Text(0.5, 1.0, 'Cylinders')

# %% [markdown]
# **Cylinders with HorsePower**

# %%
Cylinders = df.groupby('HorsePower')['Cylinders'].value_counts().reset_index()
Cylinders
# Out:
#      HorsePower  Cylinders  count
# 0          46.0          4      2
# 1          48.0          4      3
# 2          49.0          4      1
# 3          52.0          4      4
# 4          53.0          4      2
# ..          ...        ...    ...
# 114       210.0          8      1
# 115       215.0          8      3
# 116       220.0          8      1
# 117       225.0          8      3
# 118       230.0          8      1
#
# [119 rows x 3 columns]

# %%
plt.figure(figsize=(8,8))
plt.bar(Cylinders['Cylinders'],Cylinders['HorsePower'],color='darkred')
plt.title('Cylinders VS HorsePower', fontsize = 18)
plt.xlabel('Cylinders')
plt.ylabel('HorsePower')

plt.show()

# %% [markdown]
# <h2>Miles Per Gallon<h2>

# %%
df.head()
# Out:
#                         Name  Miles Per Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    HorsePower  Weight  Acceleration  Model_Year Origin
# 0       130.0    3504          12.0          70    usa
# 1       165.0    3693          11.5          70    usa
# 2       150.0    3436          11.0          70    usa
# 3       150.0    3433          12.0          70    usa
# 4       140.0    3449          10.5          70    usa

# %% [markdown]
# **Top 10 Miles Per Gallon**

# %%
top10MilesPerGallon = df.groupby('Name')['Miles Per Gallon'].value_counts().reset_index().sort_values(by='Miles Per Gallon',ascending=False).head(10)
top10MilesPerGallon
# Out:
#                                 Name  Miles Per Gallon  count
# 230                        mazda glc              46.6      1
# 222              honda civic 1500 gl              44.6      1
# 384             vw rabbit c (diesel)              44.3      1
# 381                        vw pickup              44.0      1
# 380               vw dasher (diesel)              43.4      1
# 369  volkswagen rabbit custom diesel              43.1      1
# 383                        vw rabbit              41.5      1
# 111                       datsun 210              40.8      1
# 126                   datsun b210 gx              39.4      1
# 354                   toyota starlet              39.1      1

# %%
xticks = top10MilesPerGallon['Name']
plt.figure(figsize=(8,8))
plt.bar(top10MilesPerGallon['Name'],top10MilesPerGallon['Miles Per Gallon'],color='darkred',width=0.4)
plt.xticks(xticks,rotation=90)
plt.title("MilesPerGallon VS Name")
plt.xlabel("Name")
plt.ylabel("MilesPerGallon")
plt.legend()
plt.show()

# %% [markdown]
# <h2>mpg VS cylinder<h2>

# %%
Cylinders = df.groupby('Cylinders')['Miles Per Gallon'].value_counts().reset_index()
Cylinders
# Out:
#      Cylinders  Miles Per Gallon  count
# 0            3              18.0      1
# 1            3              19.0      1
# 2            3              21.5      1
# 3            3              23.7      1
# 4            4              26.0     14
# ..         ...               ...    ...
# 152          8              20.0      1
# 153          8              20.2      1
# 154          8              23.0      1
# 155          8              23.9      1
# 156          8              26.6      1
#
# [157 rows x 3 columns]

# %%
plt.bar(Cylinders['Cylinders'],Cylinders['Miles Per Gallon'])
plt.title(' mpg VS cylinder', fontsize = 18)
plt.xlabel('cylinders', fontsize = 12)
plt.ylabel('mpg', fontsize = 12)

plt.show()

# %% [markdown]
# <h2>Top 15 companies in saving petrol<h2>

# %%
petrol = df.groupby('Name')['Miles Per Gallon'].value_counts().reset_index().sort_values(by='Miles Per Gallon',ascending=False).head(15)
petrol
# Out:
#                                   Name  Miles Per Gallon  count
# 230                          mazda glc              46.6      1
# 222                honda civic 1500 gl              44.6      1
# 384               vw rabbit c (diesel)              44.3      1
# 381                          vw pickup              44.0      1
# 380                 vw dasher (diesel)              43.4      1
# 369    volkswagen rabbit custom diesel              43.1      1
# 383                          vw rabbit              41.5      1
# 111                         datsun 210              40.8      1
# 126                     datsun b210 gx              39.4      1
# 354                     toyota starlet              39.1      1
# 277                     plymouth champ              39.0      1
# 343              toyota corolla tercel              38.1      1
# 115                      datsun 310 gx              38.0      1
# 290             plymouth horizon miser              38.0      1
# ...

# %%
xticks = petrol['Name']
plt.figure(figsize=(8,8))
plt.bar(petrol['Name'],petrol['Miles Per Gallon'])
plt.xlabel('mpg',fontsize=10)
plt.ylabel('company', fontsize=10)
plt.title('Top 15 companies in saving petrol', fontsize=15);
plt.xticks(xticks,rotation=90)
plt.show()

# %% [markdown]
# <h2>Distribution <h2>

# %%
for column in df.columns:
    if df[column].dtype!="object":
        plt.figure(figsize=(10,6))
        plt.subplot(1,2,1)
        sns.histplot(data=df,x=column,kde=True)
        plt.ylabel("freq")
        plt.xlabel(column)
        plt.title(f"distribution of {column}")
        plt.subplot(1,2,2)
        sns.boxplot(data=df,x=column)
        plt.ylabel(column)
        plt.title(f"boxplot of {column}")
        plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df.select_dtypes(['float64', 'int']).columns
n=df.select_dtypes(['int',"float"]).columns

for i in range (len(n)):
    for j in range (i+1,len(n)):
        plt.figure(figsize=(8,6))
        plt.title(f"{n[i]} vs {n[j]}")
        plt.xlabel(n[i])
        plt.ylabel(n[j])
        sns.scatterplot(data=df,x=n[i],y=n[j],hue="Origin")
        plt.show()
