# %% [markdown]
# # import necessary library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.offline import iplot
from plotly.subplots import make_subplots

# %% [markdown]
# # Reading the Data

# %%
df = pd.read_csv('/kaggle/input/premier-league-20-21/EPL_20_21.csv')

# %% [markdown]
# # Exploring the Data

# %%
df.shape
# Out:
# (532, 18)

# %%
df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# ...

# %%
df.tail()
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
#      Starts  Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 527       2   296      0        0                50                   80.0
# 528       2   180      0        0                77                   77.9
# 529       0    12      0        0                 3                  100.0
# 530       0    11      0        0                 1                  100.0
# 531       0     1      0        0                 0                   -1.0
#
# ...

# %%
df.describe()
# Out:
#               Age     Matches      Starts         Mins       Goals  \
# count  532.000000  532.000000  532.000000   532.000000  532.000000
# mean    25.500000   19.535714   15.714286  1411.443609    1.853383
# std      4.319404   11.840459   11.921161  1043.171856    3.338009
# min     16.000000    1.000000    0.000000     1.000000    0.000000
# 25%     22.000000    9.000000    4.000000   426.000000    0.000000
# 50%     26.000000   21.000000   15.000000  1345.000000    1.000000
# 75%     29.000000   30.000000   27.000000  2303.500000    2.000000
# max     38.000000   38.000000   38.000000  3420.000000   23.000000
#
#           Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# count  532.000000        532.000000             532.000000     532.000000
# mean     1.302632        717.750000              77.823872       0.191729
# std      2.149881        631.372522              13.011631       0.850881
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   532 non-null    object
#  1   Club                   532 non-null    object
#  2   Nationality            532 non-null    object
#  3   Position               532 non-null    object
#  4   Age                    532 non-null    int64
#  5   Matches                532 non-null    int64
#  6   Starts                 532 non-null    int64
#  7   Mins                   532 non-null    int64
#  8   Goals                  532 non-null    int64
#  9   Assists                532 non-null    int64
#  10  Passes_Attempted       532 non-null    int64
#  11  Perc_Passes_Completed  532 non-null    float64
#  12  Penalty_Goals          532 non-null    int64
#  13  Penalty_Attempted      532 non-null    int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Name                     0
# Club                     0
# Nationality              0
# Position                 0
# Age                      0
# Matches                  0
# Starts                   0
# Mins                     0
# Goals                    0
# Assists                  0
# Passes_Attempted         0
# Perc_Passes_Completed    0
# Penalty_Goals            0
# Penalty_Attempted        0
# xG                       0
# xA                       0
# Yellow_Cards             0
# Red_Cards                0
# dtype: int64

# %% [markdown]
# <h2>The Data does not need to be Cleaned<h2>

# %% [markdown]
# # Analysis and Visualization

# %%
df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# ...

# %% [markdown]
# <h2>The top 6 Clubs<h2>

# %% [markdown]
# <h2>Chelsea<h2>

# %%
Chelsea = df[df['Club'] == 'Chelsea']
Chelsea
# Out:
#                    Name     Club Nationality Position  Age  Matches  Starts  \
# 0           Mason Mount  Chelsea         ENG    MF,FW   21       36      32
# 1         Edouard Mendy  Chelsea         SEN       GK   28       31      31
# 2           Timo Werner  Chelsea         GER       FW   24       35      29
# 3          Ben Chilwell  Chelsea         ENG       DF   23       27      27
# 4           Reece James  Chelsea         ENG       DF   20       32      25
# 5     César Azpilicueta  Chelsea         ESP       DF   30       26      24
# 6          N'Golo Kanté  Chelsea         FRA       MF   29       30      24
# 7              Jorginho  Chelsea         ITA       MF   28       28      23
# 8          Thiago Silva  Chelsea         BRA       DF   35       23      23
# 9            Kurt Zouma  Chelsea         FRA       DF   25       24      22
# 10        Mateo Kovačić  Chelsea         CRO       MF   26       27      21
# ...

# %%
count_position = Chelsea['Position'].value_counts().reset_index()
count_position
# Out:
#   Position  count
# 0       DF     10
# 1       MF      5
# 2       FW      4
# 3       GK      3
# 4    MF,FW      2
# 5    FW,MF      2
# 6    FW,DF      1

# %%
plt.figure(figsize=(8,8))
plt.bar(count_position['Position'],count_position['count'],color='darkgreen')
plt.xlabel('Position')
plt.ylabel('Count')
plt.legend()
plt.title('Number Player in every Positions')
plt.show()

# %% [markdown]
# **From this graph we can show the number of player in every position in Chelsea**

# %%
count_nation = Chelsea['Nationality'].value_counts().reset_index()
count_nation
# Out:
#    Nationality  count
# 0          ENG      8
# 1          GER      3
# 2          ESP      3
# 3          FRA      3
# 4          ITA      2
# 5          SEN      1
# 6          BRA      1
# 7          CRO      1
# 8          USA      1
# 9          DEN      1
# 10         MAR      1
# 11         SCO      1
# 12         ARG      1

# %%
plt.figure(figsize=(8,8))
plt.bar(count_nation['Nationality'],count_nation['count'],color='darkgreen')
plt.xlabel('Nationality')
plt.ylabel('Count')
plt.legend()
plt.title('Number Player in every Nationality')
plt.show()

# %% [markdown]
# **we can see the more number of player are from england**

# %%
name_age = Chelsea.groupby('Name')['Age'].value_counts().reset_index()
name_age
# Out:
#                    Name  Age  count
# 0   Andreas Christensen   24      1
# 1       Antonio Rüdiger   27      1
# 2          Ben Chilwell   23      1
# 3         Billy Gilmour   19      1
# 4    Callum Hudson-Odoi   19      1
# 5     Christian Pulisic   21      1
# 6     César Azpilicueta   30      1
# 7         Edouard Mendy   28      1
# 8      Emerson Palmieri   25      1
# 9         Fikayo Tomori   22      1
# 10         Hakim Ziyech   27      1
# 11             Jorginho   28      1
# 12          Kai Havertz   21      1
# 13    Kepa Arrizabalaga   25      1
# 14           Kurt Zouma   25      1
# 15        Marcos Alonso   29      1
# 16          Mason Mount   21      1
# 17        Mateo Kovačić   26      1
# 18         N'Golo Kanté   29      1
# 19       Olivier Giroud   33      1
# 20          Reece James   20      1
# 21         Ross Barkley   26      1
# 22   Ruben Loftus-Cheek   24      1
# 23        Tammy Abraham   22      1
# 24         Thiago Silva   35      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_age['Name'],name_age['Age'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Age')
plt.xticks(name_age['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Age')
plt.show()

# %% [markdown]
# **This Graph show the age of every player in the team**

# %%
name_nummatches = Chelsea.groupby('Name')['Matches'].value_counts().reset_index()
name_nummatches
# Out:
#                    Name  Matches  count
# 0   Andreas Christensen       17      1
# 1       Antonio Rüdiger       19      1
# 2          Ben Chilwell       27      1
# 3         Billy Gilmour        5      1
# 4    Callum Hudson-Odoi       23      1
# 5     Christian Pulisic       27      1
# 6     César Azpilicueta       26      1
# 7         Edouard Mendy       31      1
# 8      Emerson Palmieri        2      1
# 9         Fikayo Tomori        1      1
# 10         Hakim Ziyech       23      1
# 11             Jorginho       28      1
# 12          Kai Havertz       27      1
# 13    Kepa Arrizabalaga        7      1
# 14           Kurt Zouma       24      1
# 15        Marcos Alonso       13      1
# 16          Mason Mount       36      1
# 17        Mateo Kovačić       27      1
# 18         N'Golo Kanté       30      1
# 19       Olivier Giroud       17      1
# 20          Reece James       32      1
# 21         Ross Barkley        2      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_nummatches['Name'],name_nummatches['Matches'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Matches')
plt.xticks(name_nummatches['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Matches')
plt.show()

# %% [markdown]
# **This graph show the number of Matches every player are play**

# %%
name_mins = Chelsea.groupby('Name')['Mins'].value_counts().reset_index()
name_mins
# Out:
#                    Name  Mins  count
# 0   Andreas Christensen  1371      1
# 1       Antonio Rüdiger  1710      1
# 2          Ben Chilwell  2286      1
# 3         Billy Gilmour   261      1
# 4    Callum Hudson-Odoi  1059      1
# 5     Christian Pulisic  1738      1
# 6     César Azpilicueta  2188      1
# 7         Edouard Mendy  2745      1
# 8      Emerson Palmieri    90      1
# 9         Fikayo Tomori    45      1
# 10         Hakim Ziyech  1172      1
# 11             Jorginho  2010      1
# 12          Kai Havertz  1520      1
# 13    Kepa Arrizabalaga   585      1
# 14           Kurt Zouma  2029      1
# 15        Marcos Alonso   960      1
# 16          Mason Mount  2890      1
# 17        Mateo Kovačić  1815      1
# 18         N'Golo Kanté  2146      1
# 19       Olivier Giroud   748      1
# 20          Reece James  2373      1
# 21         Ross Barkley    42      1
# 22   Ruben Loftus-Cheek    60      1
# 23        Tammy Abraham  1040      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_mins['Name'],name_mins['Mins'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('MINS')
plt.xticks(name_mins['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS MINS')
plt.show()

# %% [markdown]
# **This graph show the number of Mins every player are play**

# %%
name_goal = Chelsea.groupby('Name')['Goals'].value_counts().reset_index()
name_goal
# Out:
#                    Name  Goals  count
# 0   Andreas Christensen      0      1
# 1       Antonio Rüdiger      1      1
# 2          Ben Chilwell      3      1
# 3         Billy Gilmour      0      1
# 4    Callum Hudson-Odoi      2      1
# 5     Christian Pulisic      4      1
# 6     César Azpilicueta      1      1
# 7         Edouard Mendy      0      1
# 8      Emerson Palmieri      0      1
# 9         Fikayo Tomori      0      1
# 10         Hakim Ziyech      2      1
# 11             Jorginho      7      1
# 12          Kai Havertz      4      1
# 13    Kepa Arrizabalaga      0      1
# 14           Kurt Zouma      5      1
# 15        Marcos Alonso      2      1
# 16          Mason Mount      6      1
# 17        Mateo Kovačić      0      1
# 18         N'Golo Kanté      0      1
# 19       Olivier Giroud      4      1
# 20          Reece James      1      1
# 21         Ross Barkley      0      1
# 22   Ruben Loftus-Cheek      0      1
# 23        Tammy Abraham      6      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_goal['Name'],name_goal['Goals'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Goals')
plt.xticks(name_goal['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Goals')
plt.show()

# %% [markdown]
# **This Graph show number of Goals for every player in Chelsea**

# %%
name_assit = Chelsea.groupby('Name')['Assists'].value_counts().reset_index()
name_assit
# Out:
#                    Name  Assists  count
# 0   Andreas Christensen        0      1
# 1       Antonio Rüdiger        0      1
# 2          Ben Chilwell        5      1
# 3         Billy Gilmour        0      1
# 4    Callum Hudson-Odoi        3      1
# 5     Christian Pulisic        2      1
# 6     César Azpilicueta        2      1
# 7         Edouard Mendy        0      1
# 8      Emerson Palmieri        0      1
# 9         Fikayo Tomori        0      1
# 10         Hakim Ziyech        3      1
# 11             Jorginho        1      1
# 12          Kai Havertz        3      1
# 13    Kepa Arrizabalaga        0      1
# 14           Kurt Zouma        0      1
# 15        Marcos Alonso        0      1
# 16          Mason Mount        5      1
# 17        Mateo Kovačić        1      1
# 18         N'Golo Kanté        2      1
# 19       Olivier Giroud        0      1
# 20          Reece James        2      1
# 21         Ross Barkley        0      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_assit['Name'],name_assit['Assists'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Assists')
plt.xticks(name_assit['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Assists')
plt.show()

# %% [markdown]
# **This Graph show number of Assist for every player in Chelsea**

# %%
name_passes = Chelsea.groupby('Name')['Passes_Attempted'].value_counts().reset_index()
name_passes
# Out:
#                    Name  Passes_Attempted  count
# 0   Andreas Christensen              1089      1
# 1       Antonio Rüdiger              1476      1
# 2          Ben Chilwell              1806      1
# 3         Billy Gilmour               215      1
# 4    Callum Hudson-Odoi               659      1
# 5     Christian Pulisic               690      1
# 6     César Azpilicueta              2015      1
# 7         Edouard Mendy              1007      1
# 8      Emerson Palmieri                63      1
# 9         Fikayo Tomori                29      1
# 10         Hakim Ziyech               734      1
# 11             Jorginho              1739      1
# 12          Kai Havertz               765      1
# 13    Kepa Arrizabalaga               243      1
# 14           Kurt Zouma              1720      1
# 15        Marcos Alonso               592      1
# 16          Mason Mount              1881      1
# 17        Mateo Kovačić              1737      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_passes['Name'],name_passes['Passes_Attempted'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Passes_Attempted')
plt.xticks(name_passes['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Passes_Attempted')
plt.show()

# %% [markdown]
# **This Graph show number of Passes_Attempted for every player in Chelsea**

# %% [markdown]
# <h2>Liverpool<h2>

# %%
Liverpool = df[df['Club'] == 'Liverpool FC']
Liverpool
# Out:
#                         Name          Club Nationality Position  Age  Matches  \
# 80          Andrew Robertson  Liverpool FC         SCO       DF   26       38
# 81             Mohamed Salah  Liverpool FC         EGY       FW   28       37
# 82    Trent Alexander-Arnold  Liverpool FC         ENG       DF   21       36
# 83       Georginio Wijnaldum  Liverpool FC         NED       MF   29       38
# 84                   Alisson  Liverpool FC         BRA       GK   27       33
# 85           Roberto Firmino  Liverpool FC         BRA       FW   28       36
# 86                Sadio Mané  Liverpool FC         SEN       FW   28       35
# 87                   Fabinho  Liverpool FC         BRA    DF,MF   26       30
# 88          Thiago Alcántara  Liverpool FC         ESP       MF   29       24
# 89          Jordan Henderson  Liverpool FC         ENG    MF,DF   30       21
# 90        Nathaniel Phillips  Liverpool FC         ENG       DF   23       17
# ...

# %%
count_position = Liverpool['Position'].value_counts().reset_index()
count_position
# Out:
#   Position  count
# 0       DF     10
# 1       FW      5
# 2       MF      4
# 3       GK      3
# 4    MF,DF      2
# 5    MF,FW      2
# 6    DF,MF      1
# 7    FW,MF      1

# %%
plt.figure(figsize=(8,8))
plt.bar(count_position['Position'],count_position['count'],color='darkgreen')
plt.xlabel('Position')
plt.ylabel('Count')
plt.legend()
plt.title('Number Player in every Positions')
plt.show()

# %% [markdown]
# **From this graph we can show the number of player in every position in Liverpool**

# %%
count_nation = Liverpool['Nationality'].value_counts().reset_index()
count_nation
# Out:
#    Nationality  count
# 0          ENG      8
# 1          BRA      3
# 2          NED      2
# 3          ESP      2
# 4          SCO      1
# 5          SUI      1
# 6          IRL      1
# 7          BEL      1
# 8          JPN      1
# 9          WAL      1
# 10         TUR      1
# 11         GUI      1
# 12         CMR      1
# 13         EGY      1
# 14         POR      1
# 15         SEN      1
# 16         GRE      1

# %%
plt.figure(figsize=(8,8))
plt.bar(count_nation['Nationality'],count_nation['count'],color='darkgreen')
plt.xlabel('Nationality')
plt.ylabel('Count')
plt.legend()
plt.title('Number Player in every Nationality')
plt.show()

# %% [markdown]
# **From this graph we can show the number of player in every Nationality in Liverpool**

# %%
name_age = Liverpool.groupby('Name')['Age'].value_counts().reset_index()
name_age
# Out:
#                        Name  Age  count
# 0                    Adrián   33      1
# 1   Alex Oxlade-Chamberlain   26      1
# 2                   Alisson   27      1
# 3          Andrew Robertson   26      1
# 4         Caoimhín Kelleher   21      1
# 5              Curtis Jones   19      1
# 6                Diogo Jota   23      1
# 7              Divock Origi   25      1
# 8                   Fabinho   26      1
# 9       Georginio Wijnaldum   29      1
# 10             James Milner   34      1
# 11                Joe Gomez   23      1
# 12         Jordan Henderson   30      1
# 13               Joël Matip   28      1
# 14          Kostas Tsimikas   24      1
# 15            Mohamed Salah   28      1
# 16               Naby Keïta   25      1
# 17       Nathaniel Phillips   23      1
# 18            Neco Williams   19      1
# 19               Ozan Kabak   20      1
# 20            Rhys Williams   19      1
# 21          Roberto Firmino   28      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_age['Name'],name_age['Age'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Age')
plt.xticks(name_age['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Age')
plt.show()

# %% [markdown]
# **From this graph we can show the AGE of every player in Liverpool**

# %%
name_nummatches = Liverpool.groupby('Name')['Matches'].value_counts().reset_index()
name_nummatches
# Out:
#                        Name  Matches  count
# 0                    Adrián        3      1
# 1   Alex Oxlade-Chamberlain       13      1
# 2                   Alisson       33      1
# 3          Andrew Robertson       38      1
# 4         Caoimhín Kelleher        2      1
# 5              Curtis Jones       24      1
# 6                Diogo Jota       19      1
# 7              Divock Origi        9      1
# 8                   Fabinho       30      1
# 9       Georginio Wijnaldum       38      1
# 10             James Milner       26      1
# 11                Joe Gomez        7      1
# 12         Jordan Henderson       21      1
# 13               Joël Matip       10      1
# 14          Kostas Tsimikas        2      1
# 15            Mohamed Salah       37      1
# 16               Naby Keïta       10      1
# 17       Nathaniel Phillips       17      1
# 18            Neco Williams        6      1
# 19               Ozan Kabak        9      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_nummatches['Name'],name_nummatches['Matches'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Matches')
plt.xticks(name_nummatches['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Matches')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Mathes they play in Liverpool**

# %%
name_mins = Liverpool.groupby('Name')['Mins'].value_counts().reset_index()
name_mins
# Out:
#                        Name  Mins  count
# 0                    Adrián   270      1
# 1   Alex Oxlade-Chamberlain   253      1
# 2                   Alisson  2970      1
# 3          Andrew Robertson  3383      1
# 4         Caoimhín Kelleher   180      1
# 5              Curtis Jones  1179      1
# 6                Diogo Jota  1112      1
# 7              Divock Origi   186      1
# 8                   Fabinho  2567      1
# 9       Georginio Wijnaldum  2941      1
# 10             James Milner  1070      1
# 11                Joe Gomez   590      1
# 12         Jordan Henderson  1704      1
# 13               Joël Matip   691      1
# 14          Kostas Tsimikas     7      1
# 15            Mohamed Salah  3078      1
# 16               Naby Keïta   520      1
# 17       Nathaniel Phillips  1456      1
# 18            Neco Williams   249      1
# 19               Ozan Kabak   801      1
# 20            Rhys Williams   661      1
# 21          Roberto Firmino  2838      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_mins['Name'],name_mins['Mins'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('MINS')
plt.xticks(name_mins['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS MINS')
plt.show()

# %% [markdown]
# **From this graph we can show the number of MINS for every player are play in Liverpool**

# %%
name_goal = Liverpool.groupby('Name')['Goals'].value_counts().reset_index()
name_goal
# Out:
#                        Name  Goals  count
# 0                    Adrián      0      1
# 1   Alex Oxlade-Chamberlain      1      1
# 2                   Alisson      1      1
# 3          Andrew Robertson      1      1
# 4         Caoimhín Kelleher      0      1
# 5              Curtis Jones      1      1
# 6                Diogo Jota      9      1
# 7              Divock Origi      0      1
# 8                   Fabinho      0      1
# 9       Georginio Wijnaldum      2      1
# 10             James Milner      0      1
# 11                Joe Gomez      0      1
# 12         Jordan Henderson      1      1
# 13               Joël Matip      1      1
# 14          Kostas Tsimikas      0      1
# 15            Mohamed Salah     22      1
# 16               Naby Keïta      0      1
# 17       Nathaniel Phillips      1      1
# 18            Neco Williams      0      1
# 19               Ozan Kabak      0      1
# 20            Rhys Williams      0      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_goal['Name'],name_goal['Goals'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Goals')
plt.xticks(name_goal['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Goals')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Goals player sccoer in Liverpool**

# %%
name_assit = Liverpool.groupby('Name')['Assists'].value_counts().reset_index()
name_assit
# Out:
#                        Name  Assists  count
# 0                    Adrián        0      1
# 1   Alex Oxlade-Chamberlain        1      1
# 2                   Alisson        0      1
# 3          Andrew Robertson        7      1
# 4         Caoimhín Kelleher        0      1
# 5              Curtis Jones        2      1
# 6                Diogo Jota        0      1
# 7              Divock Origi        0      1
# 8                   Fabinho        0      1
# 9       Georginio Wijnaldum        0      1
# 10             James Milner        1      1
# 11                Joe Gomez        0      1
# 12         Jordan Henderson        1      1
# 13               Joël Matip        2      1
# 14          Kostas Tsimikas        0      1
# 15            Mohamed Salah       13      1
# 16               Naby Keïta        0      1
# 17       Nathaniel Phillips        1      1
# 18            Neco Williams        0      1
# 19               Ozan Kabak        0      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_assit['Name'],name_assit['Assists'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Assists')
plt.xticks(name_assit['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Assists')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Assist player sccoer in Liverpool**

# %%
name_passes = Liverpool.groupby('Name')['Passes_Attempted'].value_counts().reset_index()
name_passes
# Out:
#                        Name  Passes_Attempted  count
# 0                    Adrián                99      1
# 1   Alex Oxlade-Chamberlain               138      1
# 2                   Alisson              1137      1
# 3          Andrew Robertson              3214      1
# 4         Caoimhín Kelleher                62      1
# 5              Curtis Jones               976      1
# 6                Diogo Jota               451      1
# 7              Divock Origi                60      1
# 8                   Fabinho              2049      1
# 9       Georginio Wijnaldum              1747      1
# 10             James Milner               913      1
# 11                Joe Gomez               532      1
# 12         Jordan Henderson              1812      1
# 13               Joël Matip               527      1
# 14          Kostas Tsimikas                 8      1
# 15            Mohamed Salah              1288      1
# 16               Naby Keïta               356      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_passes['Name'],name_passes['Passes_Attempted'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Passes_Attempted')
plt.xticks(name_passes['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Passes_Attempted')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Passes_Attempted player sccoer in Liverpool**

# %% [markdown]
# <h2>Arsenal<h2>

# %%
Arsenal = df[df['Club'] == 'Arsenal']
Arsenal
# Out:
#                           Name     Club Nationality Position  Age  Matches  \
# 183                 Bernd Leno  Arsenal         GER       GK   28       35
# 184                Bukayo Saka  Arsenal         ENG    FW,DF   18       32
# 185               Granit Xhaka  Arsenal         SUI    MF,DF   27       31
# 186                Rob Holding  Arsenal         ENG       DF   24       30
# 187  Pierre-Emerick Aubameyang  Arsenal         GAB       FW   31       29
# 188             Kieran Tierney  Arsenal         SCO       DF   23       27
# 189            Héctor Bellerín  Arsenal         ESP       DF   25       25
# 190         Gabriel Dos Santos  Arsenal         BRA       DF   22       23
# 191        Alexandre Lacazette  Arsenal         FRA       FW   29       31
# 192              Thomas Partey  Arsenal         GHA       MF   27       24
# 193           Emile Smith-Rowe  Arsenal         ENG    MF,FW   20       20
# ...

# %%
count_position = Arsenal['Position'].value_counts().reset_index()
count_position
# Out:
#   Position  count
# 0       DF     11
# 1       FW      6
# 2       MF      5
# 3       GK      3
# 4    FW,DF      1
# 5    MF,DF      1
# 6    MF,FW      1
# 7    FW,MF      1

# %%
plt.figure(figsize=(8,8))
plt.bar(count_position['Position'],count_position['count'],color='darkgreen')
plt.xlabel('Position')
plt.ylabel('Count')
plt.legend()
plt.title('Number Player in every Positions')
plt.show()

# %% [markdown]
# **From this graph we can show the number of player in every position in Arsenal**

# %%
count_nation = Arsenal['Nationality'].value_counts().reset_index()
count_nation
# Out:
#    Nationality  count
# 0          ENG      8
# 1          BRA      4
# 2          ESP      3
# 3          GER      2
# 4          SUI      1
# 5          GAB      1
# 6          SCO      1
# 7          FRA      1
# 8          GHA      1
# 9          EGY      1
# 10         CIV      1
# 11         NOR      1
# 12         POR      1
# 13         AUS      1
# 14         BIH      1
# 15         ISL      1

# %%
plt.figure(figsize=(8,8))
plt.bar(count_nation['Nationality'],count_nation['count'],color='darkgreen')
plt.xlabel('Nationality')
plt.ylabel('Count')
plt.legend()
plt.title('Number Player in every Nationality')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Nationality in Arsenal**

# %%
name_age = Arsenal.groupby('Name')['Age'].value_counts().reset_index()
name_age
# Out:
#                          Name  Age  count
# 0      Ainsley Maitland-Niles   22      1
# 1         Alexandre Lacazette   29      1
# 2                  Bernd Leno   28      1
# 3                 Bukayo Saka   18      1
# 4              Calum Chambers   25      1
# 5               Cédric Soares   28      1
# 6               Dani Ceballos   23      1
# 7                  David Luiz   33      1
# 8               Eddie Nketiah   21      1
# 9            Emile Smith-Rowe   20      1
# 10         Gabriel Dos Santos   22      1
# 11               Granit Xhaka   27      1
# 12            Héctor Bellerín   25      1
# 13                Joe Willock   20      1
# 14             Kieran Tierney   23      1
# 15            Martin Ødegaard   21      1
# 16                 Martinelli   19      1
# 17                Mathew Ryan   28      1
# 18             Mohamed Elneny   28      1
# 19               Nicolas Pépé   25      1
# 20                 Pablo Marí   26      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_age['Name'],name_age['Age'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Age')
plt.xticks(name_age['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Age')
plt.show()

# %% [markdown]
# **From this graph we can show the Age of Player in Arsenal**

# %%
name_nummatches = Arsenal.groupby('Name')['Matches'].value_counts().reset_index()
name_nummatches
# Out:
#                          Name  Matches  count
# 0      Ainsley Maitland-Niles       11      1
# 1         Alexandre Lacazette       31      1
# 2                  Bernd Leno       35      1
# 3                 Bukayo Saka       32      1
# 4              Calum Chambers       10      1
# 5               Cédric Soares       10      1
# 6               Dani Ceballos       25      1
# 7                  David Luiz       20      1
# 8               Eddie Nketiah       17      1
# 9            Emile Smith-Rowe       20      1
# 10         Gabriel Dos Santos       23      1
# 11               Granit Xhaka       31      1
# 12            Héctor Bellerín       25      1
# 13                Joe Willock        7      1
# 14             Kieran Tierney       27      1
# 15            Martin Ødegaard       14      1
# 16                 Martinelli       14      1
# 17                Mathew Ryan        3      1
# 18             Mohamed Elneny       23      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_nummatches['Name'],name_nummatches['Matches'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Matches')
plt.xticks(name_nummatches['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Matches')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Matches every player are play in Arsenal**

# %%
name_mins = Arsenal.groupby('Name')['Mins'].value_counts().reset_index()
name_mins
# Out:
#                          Name  Mins  count
# 0      Ainsley Maitland-Niles   490      1
# 1         Alexandre Lacazette  1923      1
# 2                  Bernd Leno  3131      1
# 3                 Bukayo Saka  2553      1
# 4              Calum Chambers   753      1
# 5               Cédric Soares   746      1
# 6               Dani Ceballos  1615      1
# 7                  David Luiz  1396      1
# 8               Eddie Nketiah   423      1
# 9            Emile Smith-Rowe  1440      1
# 10         Gabriel Dos Santos  1996      1
# 11               Granit Xhaka  2522      1
# 12            Héctor Bellerín  2089      1
# 13                Joe Willock   238      1
# 14             Kieran Tierney  2299      1
# 15            Martin Ødegaard   866      1
# 16                 Martinelli   589      1
# 17                Mathew Ryan   270      1
# 18             Mohamed Elneny  1544      1
# 19               Nicolas Pépé  1616      1
# 20                 Pablo Marí   900      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_mins['Name'],name_mins['Mins'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('MINS')
plt.xticks(name_mins['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS MINS')
plt.show()

# %% [markdown]
# **From this graph we can show the number of MINS every player are play in Arsenal**

# %%
name_goal = Arsenal.groupby('Name')['Goals'].value_counts().reset_index()
name_goal
# Out:
#                          Name  Goals  count
# 0      Ainsley Maitland-Niles      0      1
# 1         Alexandre Lacazette     13      1
# 2                  Bernd Leno      0      1
# 3                 Bukayo Saka      5      1
# 4              Calum Chambers      0      1
# 5               Cédric Soares      0      1
# 6               Dani Ceballos      0      1
# 7                  David Luiz      1      1
# 8               Eddie Nketiah      2      1
# 9            Emile Smith-Rowe      2      1
# 10         Gabriel Dos Santos      2      1
# 11               Granit Xhaka      1      1
# 12            Héctor Bellerín      1      1
# 13                Joe Willock      0      1
# 14             Kieran Tierney      1      1
# 15            Martin Ødegaard      1      1
# 16                 Martinelli      2      1
# 17                Mathew Ryan      0      1
# 18             Mohamed Elneny      1      1
# 19               Nicolas Pépé     10      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_goal['Name'],name_goal['Goals'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Goals')
plt.xticks(name_goal['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Goals')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Goals every player are sccocer in Arsenal**

# %%
name_assit = Arsenal.groupby('Name')['Assists'].value_counts().reset_index()
name_assit
# Out:
#                          Name  Assists  count
# 0      Ainsley Maitland-Niles        0      1
# 1         Alexandre Lacazette        2      1
# 2                  Bernd Leno        0      1
# 3                 Bukayo Saka        3      1
# 4              Calum Chambers        2      1
# 5               Cédric Soares        1      1
# 6               Dani Ceballos        3      1
# 7                  David Luiz        0      1
# 8               Eddie Nketiah        1      1
# 9            Emile Smith-Rowe        4      1
# 10         Gabriel Dos Santos        0      1
# 11               Granit Xhaka        2      1
# 12            Héctor Bellerín        2      1
# 13                Joe Willock        0      1
# 14             Kieran Tierney        3      1
# 15            Martin Ødegaard        2      1
# 16                 Martinelli        1      1
# 17                Mathew Ryan        0      1
# 18             Mohamed Elneny        0      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_assit['Name'],name_assit['Assists'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Assists')
plt.xticks(name_assit['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Assists')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Assists every player are do in Arsenal**

# %%
name_passes = Arsenal.groupby('Name')['Passes_Attempted'].value_counts().reset_index()
name_passes
# Out:
#                          Name  Passes_Attempted  count
# 0      Ainsley Maitland-Niles               288      1
# 1         Alexandre Lacazette               524      1
# 2                  Bernd Leno              1156      1
# 3                 Bukayo Saka              1155      1
# 4              Calum Chambers               575      1
# 5               Cédric Soares               463      1
# 6               Dani Ceballos              1286      1
# 7                  David Luiz               965      1
# 8               Eddie Nketiah                89      1
# 9            Emile Smith-Rowe               724      1
# 10         Gabriel Dos Santos              1492      1
# 11               Granit Xhaka              2164      1
# 12            Héctor Bellerín              1302      1
# 13                Joe Willock                91      1
# 14             Kieran Tierney              1490      1
# 15            Martin Ødegaard               521      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_passes['Name'],name_passes['Passes_Attempted'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Passes_Attempted')
plt.xticks(name_passes['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Passes_Attempted')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Passes_Attempted every player are do in Arsenal**

# %% [markdown]
# <h2>Manchester United<h2>

# %%
United = df[df['Club'] == 'Manchester United']
United
# Out:
#                    Name               Club Nationality Position  Age  Matches  \
# 51      Bruno Fernandes  Manchester United         POR       MF   25       37
# 52    Aaron Wan-Bissaka  Manchester United         ENG       DF   22       34
# 53        Harry Maguire  Manchester United         ENG       DF   27       34
# 54      Marcus Rashford  Manchester United         ENG       FW   22       37
# 55            Luke Shaw  Manchester United         ENG       DF   25       32
# 56      Victor Lindelöf  Manchester United         SWE       DF   26       29
# 57                 Fred  Manchester United         BRA       MF   27       30
# 58         David de Gea  Manchester United         ESP       GK   29       26
# 59      Scott McTominay  Manchester United         SCO       MF   23       32
# 60           Paul Pogba  Manchester United         FRA    MF,FW   27       26
# 61      Mason Greenwood  Manchester United         ENG       FW   18       31
# ...

# %%
count_position = United['Position'].value_counts().reset_index()
count_position
# Out:
#   Position  count
# 0       DF     10
# 1       FW      9
# 2       MF      5
# 3       GK      2
# 4    MF,FW      2
# 5    FW,MF      1

# %%
plt.figure(figsize=(8,8))
plt.bar(count_position['Position'],count_position['count'],color='darkgreen')
plt.xlabel('Position')
plt.ylabel('Count')
plt.legend()
plt.title('Number Player in every Positions')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Player in every position in Manchester United**

# %%
count_nation = United['Nationality'].value_counts().reset_index()
count_nation
# Out:
#    Nationality  count
# 0          ENG     10
# 1          FRA      3
# 2          SWE      2
# 3          BRA      2
# 4          ESP      2
# 5          CIV      2
# 6          NED      2
# 7          POR      1
# 8          SCO      1
# 9          URU      1
# 10         SRB      1
# 11         WAL      1
# 12         NGA      1

# %%
plt.figure(figsize=(8,8))
plt.bar(count_nation['Nationality'],count_nation['count'],color='darkgreen')
plt.xlabel('Nationality')
plt.ylabel('Count')
plt.legend()
plt.title('Number Player in every Nationality')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Nationality for player in Manchester United**

# %%
name_age = United.groupby('Name')['Age'].value_counts().reset_index()
name_age
# Out:
#                    Name  Age  count
# 0     Aaron Wan-Bissaka   22      1
# 1           Alex Telles   27      1
# 2           Amad Diallo   18      1
# 3        Anthony Elanga   18      1
# 4       Anthony Martial   24      1
# 5         Axel Tuanzebe   22      1
# 6      Brandon Williams   19      1
# 7       Bruno Fernandes   25      1
# 8          Daniel James   22      1
# 9          David de Gea   29      1
# 10       Dean Henderson   23      1
# 11    Donny van de Beek   23      1
# 12       Edinson Cavani   33      1
# 13          Eric Bailly   26      1
# 14                 Fred   27      1
# 15      Hannibal Mejbri   17      1
# 16        Harry Maguire   27      1
# 17            Juan Mata   32      1
# 18            Luke Shaw   25      1
# 19      Marcus Rashford   22      1
# 20      Mason Greenwood   18      1
# 21        Nemanja Matić   31      1
# 22         Odion Ighalo   31      1
# 23           Paul Pogba   27      1
# 24      Scott McTominay   23      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_age['Name'],name_age['Age'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Age')
plt.xticks(name_age['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Age')
plt.show()

# %% [markdown]
# **From this graph we can show the Age of every player in Manchester United**

# %%
name_nummatches = United.groupby('Name')['Matches'].value_counts().reset_index()
name_nummatches
# Out:
#                    Name  Matches  count
# 0     Aaron Wan-Bissaka       34      1
# 1           Alex Telles        9      1
# 2           Amad Diallo        3      1
# 3        Anthony Elanga        2      1
# 4       Anthony Martial       22      1
# 5         Axel Tuanzebe        9      1
# 6      Brandon Williams        4      1
# 7       Bruno Fernandes       37      1
# 8          Daniel James       15      1
# 9          David de Gea       26      1
# 10       Dean Henderson       13      1
# 11    Donny van de Beek       19      1
# 12       Edinson Cavani       26      1
# 13          Eric Bailly       12      1
# 14                 Fred       30      1
# 15      Hannibal Mejbri        1      1
# 16        Harry Maguire       34      1
# 17            Juan Mata        9      1
# 18            Luke Shaw       32      1
# 19      Marcus Rashford       37      1
# 20      Mason Greenwood       31      1
# 21        Nemanja Matić       20      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_nummatches['Name'],name_nummatches['Matches'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Matches')
plt.xticks(name_nummatches['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Matches')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Matches every player are play in Manchester United**

# %%
name_mins = United.groupby('Name')['Mins'].value_counts().reset_index()
name_mins
# Out:
#                    Name  Mins  count
# 0     Aaron Wan-Bissaka  3060      1
# 1           Alex Telles   690      1
# 2           Amad Diallo   166      1
# 3        Anthony Elanga   155      1
# 4       Anthony Martial  1480      1
# 5         Axel Tuanzebe   404      1
# 6      Brandon Williams   188      1
# 7       Bruno Fernandes  3099      1
# 8          Daniel James   910      1
# 9          David de Gea  2295      1
# 10       Dean Henderson  1125      1
# 11    Donny van de Beek   524      1
# 12       Edinson Cavani  1375      1
# 13          Eric Bailly   916      1
# 14                 Fred  2390      1
# 15      Hannibal Mejbri     9      1
# 16        Harry Maguire  3047      1
# 17            Juan Mata   509      1
# 18            Luke Shaw  2654      1
# 19      Marcus Rashford  2920      1
# 20      Mason Greenwood  1822      1
# 21        Nemanja Matić  1106      1
# 22         Odion Ighalo    10      1
# 23           Paul Pogba  1897      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_mins['Name'],name_mins['Mins'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('MINS')
plt.xticks(name_mins['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS MINS')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Mins every player are play in Manchester United**

# %%
name_goal = United.groupby('Name')['Goals'].value_counts().reset_index()
name_goal
# Out:
#                    Name  Goals  count
# 0     Aaron Wan-Bissaka      2      1
# 1           Alex Telles      0      1
# 2           Amad Diallo      0      1
# 3        Anthony Elanga      1      1
# 4       Anthony Martial      4      1
# 5         Axel Tuanzebe      0      1
# 6      Brandon Williams      0      1
# 7       Bruno Fernandes     18      1
# 8          Daniel James      3      1
# 9          David de Gea      0      1
# 10       Dean Henderson      0      1
# 11    Donny van de Beek      1      1
# 12       Edinson Cavani     10      1
# 13          Eric Bailly      0      1
# 14                 Fred      1      1
# 15      Hannibal Mejbri      0      1
# 16        Harry Maguire      2      1
# 17            Juan Mata      1      1
# 18            Luke Shaw      1      1
# 19      Marcus Rashford     11      1
# 20      Mason Greenwood      7      1
# 21        Nemanja Matić      0      1
# 22         Odion Ighalo      0      1
# 23           Paul Pogba      3      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_goal['Name'],name_goal['Goals'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Goals')
plt.xticks(name_goal['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Goals')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Goals every player are do in Manchester United**

# %%
name_assit = United.groupby('Name')['Assists'].value_counts().reset_index()
name_assit
# Out:
#                    Name  Assists  count
# 0     Aaron Wan-Bissaka        4      1
# 1           Alex Telles        2      1
# 2           Amad Diallo        1      1
# 3        Anthony Elanga        0      1
# 4       Anthony Martial        3      1
# 5         Axel Tuanzebe        0      1
# 6      Brandon Williams        0      1
# 7       Bruno Fernandes       12      1
# 8          Daniel James        1      1
# 9          David de Gea        0      1
# 10       Dean Henderson        0      1
# 11    Donny van de Beek        1      1
# 12       Edinson Cavani        3      1
# 13          Eric Bailly        0      1
# 14                 Fred        0      1
# 15      Hannibal Mejbri        0      1
# 16        Harry Maguire        1      1
# 17            Juan Mata        2      1
# 18            Luke Shaw        5      1
# 19      Marcus Rashford        9      1
# 20      Mason Greenwood        2      1
# 21        Nemanja Matić        0      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_assit['Name'],name_assit['Assists'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Assists')
plt.xticks(name_assit['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Assists')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Assist every player are do in Manchester United**

# %%
name_passes = United.groupby('Name')['Passes_Attempted'].value_counts().reset_index()
name_passes
# Out:
#                    Name  Passes_Attempted  count
# 0     Aaron Wan-Bissaka              2065      1
# 1           Alex Telles               570      1
# 2           Amad Diallo                64      1
# 3        Anthony Elanga                53      1
# 4       Anthony Martial               488      1
# 5         Axel Tuanzebe               263      1
# 6      Brandon Williams               140      1
# 7       Bruno Fernandes              2283      1
# 8          Daniel James               304      1
# 9          David de Gea               594      1
# 10       Dean Henderson               314      1
# 11    Donny van de Beek               279      1
# 12       Edinson Cavani               343      1
# 13          Eric Bailly               547      1
# 14                 Fred              1763      1
# 15      Hannibal Mejbri                 3      1
# 16        Harry Maguire              2139      1
# 17            Juan Mata               294      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_passes['Name'],name_passes['Passes_Attempted'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Passes_Attempted')
plt.xticks(name_passes['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Passes_Attempted')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Passes_Attempted every player are do in Manchester United**

# %% [markdown]
# <h2>Manchester City<h2>

# %%
City = df[df['Club'] == 'Manchester City']
City
# Out:
#                    Name             Club Nationality Position  Age  Matches  \
# 27              Ederson  Manchester City         BRA       GK   26       36
# 28           Rúben Dias  Manchester City         POR       DF   23       32
# 29                Rodri  Manchester City         ESP       MF   24       34
# 30      Raheem Sterling  Manchester City         ENG       FW   25       31
# 31         João Cancelo  Manchester City         POR       DF   26       28
# 32       Bernardo Silva  Manchester City         POR    MF,FW   25       26
# 33       İlkay Gündoğan  Manchester City         GER       MF   29       28
# 34      Kevin De Bruyne  Manchester City         BEL       MF   29       25
# 35         Riyad Mahrez  Manchester City         ALG       FW   29       27
# 36        Gabriel Jesus  Manchester City         BRA       FW   23       29
# 37          Kyle Walker  Manchester City         ENG       DF   30       24
# ...

# %%
count_position = City['Position'].value_counts().reset_index()
count_position
# Out:
#   Position  count
# 0       DF      9
# 1       MF      4
# 2       FW      4
# 3       GK      3
# 4    FW,MF      3
# 5    MF,FW      1

# %%
plt.figure(figsize=(8,8))
plt.bar(count_position['Position'],count_position['count'],color='darkgreen')
plt.xlabel('Position')
plt.ylabel('Count')
plt.legend()
plt.title('Number Player in every Positions')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Player in every Position in Manchester City**

# %%
count_nation = City['Nationality'].value_counts().reset_index()
count_nation
# Out:
#    Nationality  count
# 0          ENG      6
# 1          BRA      3
# 2          POR      3
# 3          ESP      3
# 4          FRA      2
# 5          GER      1
# 6          BEL      1
# 7          ALG      1
# 8          UKR      1
# 9          NED      1
# 10         ARG      1
# 11         USA      1

# %%
plt.figure(figsize=(8,8))
plt.bar(count_nation['Nationality'],count_nation['count'],color='darkgreen')
plt.xlabel('Nationality')
plt.ylabel('Count')
plt.legend()
plt.title('Number Player in every Nationality')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Nationality for all player in Manchester City**

# %%
name_nummatches = City.groupby('Name')['Matches'].value_counts().reset_index()
name_nummatches
# Out:
#                    Name  Matches  count
# 0       Aymeric Laporte       16      1
# 1        Benjamin Mendy       13      1
# 2        Bernardo Silva       26      1
# 3               Ederson       36      1
# 4           Eric García        6      1
# 5           Fernandinho       21      1
# 6         Ferrán Torres       24      1
# 7         Gabriel Jesus       29      1
# 8           John Stones       22      1
# 9          João Cancelo       28      1
# 10      Kevin De Bruyne       25      1
# 11          Kyle Walker       24      1
# 12           Liam Delap        1      1
# 13           Nathan Aké       10      1
# 14  Oleksandr Zinchenko       20      1
# 15           Phil Foden       28      1
# 16      Raheem Sterling       31      1
# 17         Riyad Mahrez       27      1
# 18                Rodri       34      1
# 19           Rúben Dias       32      1
# 20         Scott Carson        1      1
# 21        Sergio Agüero       12      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_nummatches['Name'],name_nummatches['Matches'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Matches')
plt.xticks(name_nummatches['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Matches')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Matches every player are play in Manchester City**

# %%
name_mins = City.groupby('Name')['Mins'].value_counts().reset_index()
name_mins
# Out:
#                    Name  Mins  count
# 0       Aymeric Laporte  1344      1
# 1        Benjamin Mendy   953      1
# 2        Bernardo Silva  2065      1
# 3               Ederson  3240      1
# 4           Eric García   383      1
# 5           Fernandinho  1188      1
# 6         Ferrán Torres  1306      1
# 7         Gabriel Jesus  2063      1
# 8           John Stones  1933      1
# 9          João Cancelo  2299      1
# 10      Kevin De Bruyne  1997      1
# 11          Kyle Walker  1946      1
# 12           Liam Delap    40      1
# 13           Nathan Aké   797      1
# 14  Oleksandr Zinchenko  1478      1
# 15           Phil Foden  1616      1
# 16      Raheem Sterling  2536      1
# 17         Riyad Mahrez  1949      1
# 18                Rodri  2748      1
# 19           Rúben Dias  2843      1
# 20         Scott Carson    90      1
# 21        Sergio Agüero   559      1
# 22         Zack Steffen    90      1
# 23       İlkay Gündoğan  2029      1

# %%
plt.figure(figsize=(8,8))
plt.bar(name_mins['Name'],name_mins['Mins'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('MINS')
plt.xticks(name_mins['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS MINS')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Mins every player are play in Manchester City**

# %%
name_goal = City.groupby('Name')['Goals'].value_counts().reset_index()
name_goal
# Out:
#                    Name  Goals  count
# 0       Aymeric Laporte      0      1
# 1        Benjamin Mendy      2      1
# 2        Bernardo Silva      2      1
# 3               Ederson      0      1
# 4           Eric García      0      1
# 5           Fernandinho      0      1
# 6         Ferrán Torres      7      1
# 7         Gabriel Jesus      9      1
# 8           John Stones      4      1
# 9          João Cancelo      2      1
# 10      Kevin De Bruyne      6      1
# 11          Kyle Walker      1      1
# 12           Liam Delap      0      1
# 13           Nathan Aké      1      1
# 14  Oleksandr Zinchenko      0      1
# 15           Phil Foden      9      1
# 16      Raheem Sterling     10      1
# 17         Riyad Mahrez      9      1
# 18                Rodri      2      1
# 19           Rúben Dias      1      1
# 20         Scott Carson      0      1
# 21        Sergio Agüero      4      1
# 22         Zack Steffen      0      1
# 23       İlkay Gündoğan     13      1

# %%
plt.figure(figsize=(8,8))
plt.bar(name_goal['Name'],name_goal['Goals'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Goals')
plt.xticks(name_goal['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Goals')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Goals every player are do in Manchester City**

# %%
name_assit = City.groupby('Name')['Assists'].value_counts().reset_index()
name_assit
# Out:
#                    Name  Assists  count
# 0       Aymeric Laporte        0      1
# 1        Benjamin Mendy        1      1
# 2        Bernardo Silva        6      1
# 3               Ederson        1      1
# 4           Eric García        0      1
# 5           Fernandinho        2      1
# 6         Ferrán Torres        2      1
# 7         Gabriel Jesus        4      1
# 8           John Stones        0      1
# 9          João Cancelo        3      1
# 10      Kevin De Bruyne       12      1
# 11          Kyle Walker        1      1
# 12           Liam Delap        0      1
# 13           Nathan Aké        0      1
# 14  Oleksandr Zinchenko        0      1
# 15           Phil Foden        5      1
# 16      Raheem Sterling        7      1
# 17         Riyad Mahrez        6      1
# 18                Rodri        2      1
# 19           Rúben Dias        0      1
# 20         Scott Carson        0      1
# 21        Sergio Agüero        1      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_assit['Name'],name_assit['Assists'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Assists')
plt.xticks(name_assit['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Assists')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Assists every player are do in Manchester City**

# %%
name_passes = City.groupby('Name')['Passes_Attempted'].value_counts().reset_index()
name_passes
# Out:
#                    Name  Passes_Attempted  count
# 0       Aymeric Laporte              1261      1
# 1        Benjamin Mendy               651      1
# 2        Bernardo Silva              1427      1
# 3               Ederson              1090      1
# 4           Eric García               344      1
# 5           Fernandinho              1001      1
# 6         Ferrán Torres               442      1
# 7         Gabriel Jesus               754      1
# 8           John Stones              1713      1
# 9          João Cancelo              2094      1
# 10      Kevin De Bruyne              1406      1
# 11          Kyle Walker              1897      1
# 12           Liam Delap                 7      1
# 13           Nathan Aké               755      1
# 14  Oleksandr Zinchenko              1475      1
# 15           Phil Foden               838      1
# 16      Raheem Sterling              1127      1
# 17         Riyad Mahrez              1086      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_passes['Name'],name_passes['Passes_Attempted'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Passes_Attempted')
plt.xticks(name_passes['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Passes_Attempted')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Passes_Attempted every player are do in Manchester City**

# %% [markdown]
# <h2>Tottenham Hotspur F.C<h2>

# %%
totten = df[df['Club'] == 'Tottenham Hotspur']
totten
# Out:
#                   Name               Club Nationality Position  Age  Matches  \
# 159    Pierre Højbjerg  Tottenham Hotspur         DEN       MF   24       38
# 160        Hugo Lloris  Tottenham Hotspur         FRA       GK   33       38
# 161      Son Heung-min  Tottenham Hotspur         KOR       FW   28       37
# 162         Harry Kane  Tottenham Hotspur         ENG       FW   27       35
# 163          Eric Dier  Tottenham Hotspur         ENG       DF   26       28
# 164    Tanguy Ndombele  Tottenham Hotspur         FRA       MF   23       33
# 165    Sergio Reguilón  Tottenham Hotspur         ESP       DF   23       27
# 166  Toby Alderweireld  Tottenham Hotspur         BEL       DF   31       25
# 167       Serge Aurier  Tottenham Hotspur         CIV       DF   27       19
# 168   Davinson Sánchez  Tottenham Hotspur         COL       DF   24       18
# 169     Moussa Sissoko  Tottenham Hotspur         FRA       MF   30       25
# ...

# %%
count_position = totten['Position'].value_counts().reset_index()
count_position
# Out:
#   Position  count
# 0       DF      9
# 1       MF      6
# 2       FW      5
# 3    FW,MF      3
# 4       GK      1

# %%
plt.figure(figsize=(8,8))
plt.bar(count_position['Position'],count_position['count'],color='darkgreen')
plt.xlabel('Position')
plt.ylabel('Count')
plt.legend()
plt.title('Number Player in every Positions')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Player in every Position in Tottenham Hotspur**

# %%
count_nation = totten['Nationality'].value_counts().reset_index()
count_nation
# Out:
#    Nationality  count
# 0          ENG      6
# 1          FRA      3
# 2          WAL      3
# 3          BRA      2
# 4          ARG      2
# 5          DEN      1
# 6          KOR      1
# 7          ESP      1
# 8          BEL      1
# 9          CIV      1
# 10         COL      1
# 11         IRL      1
# 12         NED      1

# %%
plt.figure(figsize=(8,8))
plt.bar(count_nation['Nationality'],count_nation['count'],color='darkgreen')
plt.xlabel('Nationality')
plt.ylabel('Count')
plt.legend()
plt.title('Number Player in every Nationality')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Player in every Nationality in Tottenham Hotspur**

# %%
name_age = totten.groupby('Name')['Age'].value_counts().reset_index()
name_age
# Out:
#                  Name  Age  count
# 0          Ben Davies   27      1
# 1     Carlos Vinícius   25      1
# 2       Dane Scarlett   16      1
# 3    Davinson Sánchez   24      1
# 4           Dele Alli   24      1
# 5           Eric Dier   26      1
# 6         Gareth Bale   31      1
# 7    Giovani Lo Celso   24      1
# 8          Harry Kane   27      1
# 9         Harry Winks   24      1
# 10        Hugo Lloris   33      1
# 11    Japhet Tanganga   21      1
# 12          Joe Rodon   22      1
# 13        Lucas Moura   27      1
# 14       Matt Doherty   28      1
# 15     Moussa Sissoko   30      1
# 16    Pierre Højbjerg   24      1
# 17       Serge Aurier   27      1
# 18    Sergio Reguilón   23      1
# 19      Son Heung-min   28      1
# 20    Steven Bergwijn   22      1
# 21    Tanguy Ndombele   23      1
# 22  Toby Alderweireld   31      1
# 23        Érik Lamela   28      1

# %%
plt.figure(figsize=(8,8))
plt.bar(name_age['Name'],name_age['Age'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Age')
plt.xticks(name_age['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Age')
plt.show()

# %% [markdown]
# **From this graph we can show the Age of every player in Tottenham Hotspur**

# %%
name_nummatches = totten.groupby('Name')['Matches'].value_counts().reset_index()
name_nummatches
# Out:
#                  Name  Matches  count
# 0          Ben Davies       20      1
# 1     Carlos Vinícius        9      1
# 2       Dane Scarlett        1      1
# 3    Davinson Sánchez       18      1
# 4           Dele Alli       15      1
# 5           Eric Dier       28      1
# 6         Gareth Bale       20      1
# 7    Giovani Lo Celso       18      1
# 8          Harry Kane       35      1
# 9         Harry Winks       15      1
# 10        Hugo Lloris       38      1
# 11    Japhet Tanganga        6      1
# 12          Joe Rodon       12      1
# 13        Lucas Moura       30      1
# 14       Matt Doherty       17      1
# 15     Moussa Sissoko       25      1
# 16    Pierre Højbjerg       38      1
# 17       Serge Aurier       19      1
# 18    Sergio Reguilón       27      1
# 19      Son Heung-min       37      1
# 20    Steven Bergwijn       21      1
# 21    Tanguy Ndombele       33      1
# 22  Toby Alderweireld       25      1
# 23        Érik Lamela       23      1

# %%
plt.figure(figsize=(8,8))
plt.bar(name_nummatches['Name'],name_nummatches['Matches'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Matches')
plt.xticks(name_nummatches['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Matches')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Matches every player are play in Tottenham Hotspur**

# %%
name_mins = totten.groupby('Name')['Mins'].value_counts().reset_index()
name_mins
# Out:
#                  Name  Mins  count
# 0          Ben Davies  1346      1
# 1     Carlos Vinícius   308      1
# 2       Dane Scarlett     1      1
# 3    Davinson Sánchez  1486      1
# 4           Dele Alli   620      1
# 5           Eric Dier  2520      1
# 6         Gareth Bale   920      1
# 7    Giovani Lo Celso   945      1
# 8          Harry Kane  3082      1
# 9         Harry Winks   861      1
# 10        Hugo Lloris  3420      1
# 11    Japhet Tanganga   487      1
# 12          Joe Rodon   733      1
# 13        Lucas Moura  1411      1
# 14       Matt Doherty  1240      1
# 15     Moussa Sissoko  1585      1
# 16    Pierre Højbjerg  3420      1
# 17       Serge Aurier  1605      1
# 18    Sergio Reguilón  2244      1
# 19      Son Heung-min  3114      1
# 20    Steven Bergwijn  1208      1
# 21    Tanguy Ndombele  2091      1
# 22  Toby Alderweireld  2240      1
# 23        Érik Lamela   717      1

# %%
plt.figure(figsize=(8,8))
plt.bar(name_mins['Name'],name_mins['Mins'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('MINS')
plt.xticks(name_mins['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS MINS')
plt.show()

# %% [markdown]
# **From this graph we can show the number of MINS every player are play in Tottenham Hotspur**

# %%
name_goal = totten.groupby('Name')['Goals'].value_counts().reset_index()
name_goal
# Out:
#                  Name  Goals  count
# 0          Ben Davies      0      1
# 1     Carlos Vinícius      1      1
# 2       Dane Scarlett      0      1
# 3    Davinson Sánchez      0      1
# 4           Dele Alli      0      1
# 5           Eric Dier      0      1
# 6         Gareth Bale     11      1
# 7    Giovani Lo Celso      1      1
# 8          Harry Kane     23      1
# 9         Harry Winks      0      1
# 10        Hugo Lloris      0      1
# 11    Japhet Tanganga      0      1
# 12          Joe Rodon      0      1
# 13        Lucas Moura      3      1
# 14       Matt Doherty      0      1
# 15     Moussa Sissoko      0      1
# 16    Pierre Højbjerg      2      1
# 17       Serge Aurier      2      1
# 18    Sergio Reguilón      0      1
# 19      Son Heung-min     17      1
# 20    Steven Bergwijn      1      1
# 21    Tanguy Ndombele      3      1
# 22  Toby Alderweireld      1      1
# 23        Érik Lamela      1      1

# %%
plt.figure(figsize=(8,8))
plt.bar(name_goal['Name'],name_goal['Goals'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Goals')
plt.xticks(name_goal['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Goals')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Goals every player are do in Tottenham Hotspur**

# %%
name_assit = totten.groupby('Name')['Assists'].value_counts().reset_index()
name_assit
# Out:
#                  Name  Assists  count
# 0          Ben Davies        1      1
# 1     Carlos Vinícius        0      1
# 2       Dane Scarlett        0      1
# 3    Davinson Sánchez        0      1
# 4           Dele Alli        1      1
# 5           Eric Dier        0      1
# 6         Gareth Bale        2      1
# 7    Giovani Lo Celso        1      1
# 8          Harry Kane       14      1
# 9         Harry Winks        0      1
# 10        Hugo Lloris        0      1
# 11    Japhet Tanganga        0      1
# 12          Joe Rodon        0      1
# 13        Lucas Moura        4      1
# 14       Matt Doherty        2      1
# 15     Moussa Sissoko        0      1
# 16    Pierre Højbjerg        4      1
# 17       Serge Aurier        3      1
# 18    Sergio Reguilón        3      1
# 19      Son Heung-min       10      1
# 20    Steven Bergwijn        3      1
# 21    Tanguy Ndombele        2      1
# 22  Toby Alderweireld        0      1
# 23        Érik Lamela        0      1

# %%
plt.figure(figsize=(8,8))
plt.bar(name_assit['Name'],name_assit['Assists'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Assists')
plt.xticks(name_assit['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Assists')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Assists every player are do in Tottenham Hotspur**

# %%
name_passes = totten.groupby('Name')['Passes_Attempted'].value_counts().reset_index()
name_passes
# Out:
#                  Name  Passes_Attempted  count
# 0          Ben Davies               783      1
# 1     Carlos Vinícius                44      1
# 2       Dane Scarlett                 0      1
# 3    Davinson Sánchez               977      1
# 4           Dele Alli               337      1
# 5           Eric Dier              1654      1
# 6         Gareth Bale               408      1
# 7    Giovani Lo Celso               589      1
# 8          Harry Kane               937      1
# 9         Harry Winks               658      1
# 10        Hugo Lloris              1067      1
# 11    Japhet Tanganga               229      1
# 12          Joe Rodon               411      1
# 13        Lucas Moura               600      1
# 14       Matt Doherty               826      1
# 15     Moussa Sissoko               792      1
# 16    Pierre Højbjerg              2687      1
# 17       Serge Aurier               954      1
# 18    Sergio Reguilón              1393      1
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(name_passes['Name'],name_passes['Passes_Attempted'],color='darkgreen')
plt.xlabel('Name')
plt.ylabel('Passes_Attempted')
plt.xticks(name_passes['Name'],rotation = 90)
plt.legend()
plt.title('Name Player VS Passes_Attempted')
plt.show()

# %% [markdown]
# **From this graph we can show the number of Passes_Attempted every player are do in Tottenham Hotspur**

# %% [markdown]
# <h2>The Realation between all clubs<h2>

# %%
df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# ...

# %% [markdown]
# <h2>Goals VS Assist<h2>

# %%
goal_assist = df.groupby('Club')[['Goals','Assists']].sum().reset_index()
goal_assist
# Out:
#                        Club  Goals  Assists
# 0                   Arsenal     53       38
# 1               Aston Villa     52       38
# 2                  Brighton     39       24
# 3                   Burnley     32       20
# 4                   Chelsea     56       38
# 5            Crystal Palace     39       29
# 6                   Everton     45       32
# 7                    Fulham     26       18
# 8              Leeds United     60       45
# 9            Leicester City     64       45
# 10             Liverpool FC     65       51
# 11          Manchester City     82       55
# 12        Manchester United     70       51
# 13         Newcastle United     44       26
# 14         Sheffield United     19       13
# 15              Southampton     47       33
# 16        Tottenham Hotspur     66       50
# 17     West Bromwich Albion     33       20
# 18          West Ham United     60       46
# 19  Wolverhampton Wanderers     34       21

# %%
goal_assist_melted = goal_assist.melt(id_vars='Club', var_name='Metric', value_name='Count')
plt.figure(figsize=(10, 6))
sns.barplot(data=goal_assist_melted, x='Club', y='Count', hue='Metric')
plt.xlabel('Club')
plt.ylabel('Count')
plt.title('Total Goals and Assists for Each Club')
plt.xticks(rotation=90)
plt.legend(title='Metric')

plt.show()

# %% [markdown]
# **This Graph show the number of goals and assists for every clubs individual**

# %% [markdown]
# <h2>Red and Yellow Card<h2>

# %%
red_yellow = df.groupby('Club')[['Yellow_Cards','Red_Cards']].sum().reset_index()
red_yellow
# Out:
#                        Club  Yellow_Cards  Red_Cards
# 0                   Arsenal            49          5
# 1               Aston Villa            71          4
# 2                  Brighton            49          6
# 3                   Burnley            48          0
# 4                   Chelsea            51          3
# 5            Crystal Palace            56          2
# 6                   Everton            59          2
# 7                    Fulham            67          3
# 8              Leeds United            61          1
# 9            Leicester City            61          0
# 10             Liverpool FC            40          0
# 11          Manchester City            46          2
# 12        Manchester United            64          1
# 13         Newcastle United            65          3
# 14         Sheffield United            73          3
# 15              Southampton            52          3
# 16        Tottenham Hotspur            57          2
# ...

# %%
red_yellow_melted = goal_assist.melt(id_vars='Club', var_name='Metric', value_name='Count')
plt.figure(figsize=(10, 6))
sns.barplot(data=red_yellow_melted, x='Club', y='Count', hue='Metric')
plt.xlabel('Club')
plt.ylabel('Count')
plt.title('Total Yellow Cards and Red Cards for Each Club')
plt.xticks(rotation=90)
plt.legend(title='Metric')

# %% [markdown]
# **This Graph show the number of Red Card and Yellow Card for every clubs individual**

# %% [markdown]
# <h2>The number of Passes_Attempted every club do<h2>

# %%
Passes_Attempted = df.groupby('Club')['Passes_Attempted'].sum().reset_index()
Passes_Attempted
# Out:
#                        Club  Passes_Attempted
# 0                   Arsenal             21291
# 1               Aston Villa             16556
# 2                  Brighton             19456
# 3                   Burnley             15043
# 4                   Chelsea             25151
# 5            Crystal Palace             15092
# 6                   Everton             18246
# 7                    Fulham             18860
# 8              Leeds United             20043
# 9            Leicester City             20572
# 10             Liverpool FC             25526
# 11          Manchester City             26688
# 12        Manchester United             21960
# 13         Newcastle United             14218
# 14         Sheffield United             15843
# 15              Southampton             18761
# 16        Tottenham Hotspur             19872
# 17     West Bromwich Albion             13646
# 18          West Ham United             16358
# ...

# %%
plt.figure(figsize=(8,8))
plt.bar(Passes_Attempted['Club'],Passes_Attempted['Passes_Attempted'],color='darkgreen')
plt.xlabel('Club Name')
plt.ylabel('Passes_Attempted')
plt.xticks(Passes_Attempted['Club'],rotation = 90)
plt.legend()
plt.title('Name Club VS Passes_Attempted')
plt.show()

# %% [markdown]
# **This Graph show the number of Passes_Attempted for every clubs individual**

# %% [markdown]
# <h2>Goals VS Assists<h2>

# %%
goal_assist_pie = df[['Goals','Assists']].sum()
goal_assist_pie
# Out:
# Goals      986
# Assists    693
# dtype: int64

# %%
plt.figure(figsize=(8, 8))
plt.pie(goal_assist_pie, labels=goal_assist_pie.index, autopct='%1.1f%%', startangle=140)
plt.title('Goals and Assists')
plt.legend()
plt.show()

# %% [markdown]
# **This Graph show the number of goals and assists**

# %%
red_yellow_pie = df[['Yellow_Cards','Red_Cards']].sum()
red_yellow_pie
# Out:
# Yellow_Cards    1125
# Red_Cards         48
# dtype: int64

# %%
plt.figure(figsize=(8, 8))
plt.pie(red_yellow_pie, labels=red_yellow_pie.index, autopct='%1.1f%%', startangle=140)
plt.title('Red Card and Yellow Cards')
plt.legend()
plt.show()

# %% [markdown]
# **This Graph show the number of Red Cards and Yellow Cards**

# %%
penalty_goals = df['Penalty_Goals'].sum()
penalty_attempted = df['Penalty_Attempted'].sum()
penalty_not_scored = penalty_attempted - penalty_goals
penalty_data = [penalty_goals, penalty_not_scored]
labels = ['Penalty Goals', 'Penalty Attempts - Not Scored']
plt.figure(figsize=(8, 8))
plt.pie(penalty_data, labels=labels, autopct='%1.1f%%', startangle=140)

plt.title('Penalty Goals vs Penalty Attempts Not Scored')
plt.legend()

plt.show()

# %% [markdown]
# **This Graph show the number of Penalitygoals and PenalitynoGoals**

# %%
postion_count_all_player = df['Position'].value_counts().reset_index()
postion_count_all_player
# Out:
#   Position  count
# 0       DF    178
# 1       MF    108
# 2       FW     81
# 3    FW,MF     47
# 4       GK     42
# 5    MF,FW     36
# 6    DF,MF     15
# 7    MF,DF     13
# 8    FW,DF      6
# 9    DF,FW      6

# %%
plt.figure(figsize=(8,8))
plt.bar(postion_count_all_player['Position'],postion_count_all_player['count'],color='darkgreen')
plt.xlabel('Position')
plt.ylabel('Count')
plt.legend()
plt.title('Number of All Player in every Positions')
plt.show()

# %% [markdown]
# **From this graph we can show the number of player in every position in all Clubs**

# %%
Ags = df.groupby('Club')['Age'].mean().reset_index()
Ags
# Out:
#                        Club        Age
# 0                   Arsenal  24.965517
# 1               Aston Villa  24.291667
# 2                  Brighton  24.555556
# 3                   Burnley  27.040000
# 4                   Chelsea  25.592593
# 5            Crystal Palace  28.333333
# 6                   Everton  25.413793
# 7                    Fulham  25.035714
# 8              Leeds United  25.347826
# 9            Leicester City  25.592593
# 10             Liverpool FC  25.571429
# 11          Manchester City  25.708333
# 12        Manchester United  23.862069
# 13         Newcastle United  26.074074
# 14         Sheffield United  24.814815
# 15              Southampton  24.137931
# 16        Tottenham Hotspur  25.625000
# 17     West Bromwich Albion  26.766667
# 18          West Ham United  27.500000
# 19  Wolverhampton Wanderers  24.444444

# %%
plt.figure(figsize=(8,8))
plt.bar(Ags['Club'],Ags['Age'],color='darkgreen')
plt.xlabel('Club Name')
plt.ylabel('Average Age')
plt.xticks(Ags['Club'],rotation = 90)
plt.legend()
plt.title('Average age in every Club')
plt.show()

# %% [markdown]
# **From this graph we can show the Average of Age for All player in all Club**
